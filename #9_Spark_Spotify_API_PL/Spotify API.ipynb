# %% [markdown]
# # SPOTIFY API

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import json
import requests
from time import sleep

# %%
f = open("creds.json","r")
json_data = f.read()
creds_dict = json.loads(json_data)
f.close()

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=creds_dict["Client_ID"],
                                                           client_secret=creds_dict["Client_Secret"]))

# %% [raw]
# a_z_list = [chr(x) for x in range(ord('a'), ord('z')+1)]
#
# response_list = []
# for letter in a_z_list:
#     results = sp.search(q=letter, limit=50)
#     response_list.append(results)
#     sleep(5)
#
# f = open("spotify_data.json","a")
# f.write(json.dumps(response_list))
# f.close()

# %%
results = sp.search(q='b', limit=50)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'])
# Out:
# 0 Blinding Lights
# 1 Be Like That - feat. Swae Lee & Khalid
# 2 Blueberry Faygo
# 3 Breaking Me
# 4 Bandit (with YoungBoy Never Broke Again)
# 5 Ballin' (with Roddy Ricch)
# 6 Be Kind (with Halsey)
# 7 BOP
# 8 Blastoff (feat. Juice Wrld & Trippie Redd)
# 9 Beautiful Crazy
# 10 Bonita
# 11 Blanco
# 12 Bobo
# 13 bad guy
# 14 Blood On My Jeans
# 15 Before You Go
# 16 BLIND (feat. Young Thug)
# 17 betty
# 18 Better Now
# 19 Bang!
# 20 Bad Energy
# 21 Beer Never Broke My Heart
# 22 Break My Heart
# 23 Broke In A Minute
# 24 Bruises
# 25 Believer
# 26 Black & White
# 27 BUTTERFLY EFFECT
# 28 bloody valentine
# 29 Boss Bitch
# 30 WAP (feat. Megan Thee Stallion)
# 31 For The Night (feat. Lil Baby & DaBaby)
# 32 ROCKSTAR (feat. Roddy Ricch)
# 33 The Box
# 34 my ex's best friend (with blackbear)
# 35 exile (feat. Bon Iver)
# 36 death bed (coffee for your head)
# 37 Sunday Best
# 38 you broke me first
# 39 Savage Love (Laxed - Siren Beat)
# 40 The Bigger Picture
# ...

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=b&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
# ...

# %%
print("result keys: ",list(results.keys()))
print("tracks keys: ",list(results["tracks"].keys()))
print("items is list: ", type(results["tracks"]["items"])==list, ", with len: ", len(results["tracks"]["items"]))

print("\nitems keys: ",list(results["tracks"]["items"][0].keys()))

print("\nalbum keys: ",list(results["tracks"]["items"][0]["album"].keys()))

print("\nalbum id: ",results["tracks"]["items"][0]["album"]["id"])
print("number of album artists: ",len(results["tracks"]["items"][0]["album"]["artists"]))
album_artists = results["tracks"]["items"][0]["album"]["artists"]
album_artists_list = [artist["name"] for artist in album_artists]
print("album artists: ",album_artists_list)
print("album name: ",results["tracks"]["items"][0]["album"]["name"])
print("album total tracks: ",results["tracks"]["items"][0]["album"]["total_tracks"])
print("album release date: ",results["tracks"]["items"][0]["album"]["release_date"])

print("\ntrack name: ",results["tracks"]["items"][0]["name"])
print("track id: ",results["tracks"]["items"][0]["id"])
track_artists = results["tracks"]["items"][0]["artists"]
track_artists_list = [artist["name"] for artist in album_artists]
print("track artists: ",track_artists_list)
print("track duration: ",results["tracks"]["items"][0]["duration_ms"])
print("track number: ",results["tracks"]["items"][0]["track_number"])
print("track type: ",results["tracks"]["items"][0]["type"])
print("track popularity: ",results["tracks"]["items"][0]["popularity"])
print("track explicity: ",results["tracks"]["items"][0]["explicit"])
# Out:
# result keys:  ['tracks']
# tracks keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# items is list:  True , with len:  50
#
# items keys:  ['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri']
#
# album keys:  ['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri']
#
# album id:  4yP0hdKOZPNshxUOjY0cZj
# number of album artists:  1
# album artists:  ['The Weeknd']
# album name:  After Hours
# album total tracks:  14
# album release date:  2020-03-20
#
# track name:  Blinding Lights
# track id:  0VjIjW4GlUZAMYd2vXMi3b
# track artists:  ['The Weeknd']
# track duration:  200040
# track number:  9
# track type:  track
# track popularity:  98
# track explicity:  False

# %%
results["tracks"]['next']
# Out:
# 'https://api.spotify.com/v1/search?query=b&type=track&offset=50&limit=50'

# %%
results["tracks"]['total']
# Out:
# 100019

# %%
len(results["tracks"]["items"])
# Out:
# 50

# %%
results["tracks"]["items"][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
print("Album: ",results["tracks"]["items"][0]["album"]["name"])
print("Artists: ",results["tracks"]["items"][0]["album"]["artists"][0]["name"])
# Out:
# Album:  After Hours
# Artists:  The Weeknd

# %%
response = requests.get("https://api.spotify.com/v1/search?query=b&type=track&offset=50&limit=50")
response.text
# Out:
# '{\n  "error": {\n    "status": 401,\n    "message": "No token provided"\n  }\n}'
